# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_netflix = pd.read_csv('./datasets/netflix_daily_top_10.csv')

# %%
# Tipos dos dados
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
df_netflix['As of'] = pd.to_datetime(df_netflix['As of'])

# Período da análise feita
[df_netflix['As of'].min(), df_netflix['As of'].max()]
# Out:
# [Timestamp('2020-04-01 00:00:00'), Timestamp('2022-03-11 00:00:00')]

# %%
# Tamanho da base de dados
df_netflix.shape
# Out:
# (7100, 10)

# %%
# Verificação de dados nulos
df_netflix.isna().sum()

# Tratamento dos dados nulos
df_netflix['Netflix Exclusive'] = df_netflix['Netflix Exclusive'].fillna('No')

# %%
df_netflix['Days In Top 10'].plot.box()
plt.show()
df_netflix['Viewership Score'].plot.box()
# Out:
# <Axes: >

# %%
df_netflix['Days In Top 10'].hist()
# Out:
# <Axes: >

# %%
df_netflix['Days In Top 10'].hist()
df_netflix['Title'].value_counts()
# Out:
# Title
# Cocomelon                       428
# Ozark                            85
# Cobra Kai                        81
# Manifest                         80
# The Queenâs Gambit             73
#                                ...
# The Lucky One                     1
# Fistful of Vengeance              1
# Dark Shadows                      1
# Scary Stories to Tell in th…      1
# Chosen                            1
# Name: count, Length: 645, dtype: int64

# %%
df_netflix['Viewership Score'].hist()
# Out:
# <Axes: >

# %%
# Out:
#                        Title  Days In Top 10  Viewership Score  Points Per Day
# 358            Pieces of Her               7                68        9.714286
# 574  The Woman in the Window              11               100        9.090909
# 69                Below Zero               6                54        9.000000
# 250           Inventing Anna              28               250        8.928571
# 61                  Bad Trip               9                78        8.666667
# ..                       ...             ...               ...             ...
# 83        Bo Burnham: Inside               2                 2        1.000000
# 364            Puss in Boots               2                 2        1.000000
# 75              Black Island               2                 2        1.000000
# 384    Rust Valley Restorers               3                 3        1.000000
# 10                60 Days In               4                 4        1.000000
#
# [645 rows x 4 columns]
